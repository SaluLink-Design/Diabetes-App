# %% [markdown]
# <a href="https://colab.research.google.com/github/SaluLink-Design/Authi-1.0-Diabetes/blob/main/Authi%201.0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM
import torch

# %%
model_name = "emilyalsentzer/Bio_ClinicalBERT"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForMaskedLM.from_pretrained(model_name)
model.eval()
# Out:
# BertForMaskedLM(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (cls): BertOnlyMLMHead(
#     (predictions): BertLMPredictionHead(
#       (transform): BertPredictionHeadTransform(
#         (dense): Linear(in_features=768, out_features=768, bias=True)
#         (transform_act_fn): GELUActivation()
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#       (decoder): Linear(in_features=768, out_features=28996, bias=True)
#     )
#   )
# )

# %%
def fill_mask(text, top_k=5):
    """
    Given a clinical note with [MASK], returns top predicted words.
    Example:
        fill_mask("The patient was diagnosed with [MASK] disease.")
    """
    inputs = tokenizer(text, return_tensors="pt")
    mask_token_index = torch.where(inputs["input_ids"] == tokenizer.mask_token_id)[1]

    with torch.no_grad():
        logits = model(**inputs).logits

    mask_token_logits = logits[0, mask_token_index, :]
    top_tokens = torch.topk(mask_token_logits, top_k, dim=1).indices[0].tolist()

    results = []
    for token in top_tokens:
        word = tokenizer.decode([token]).strip()
        sentence = text.replace("[MASK]", word)
        results.append(sentence)

    return results

# %%
sentences = fill_mask("The patient was diagnosed with [MASK] disease.")
for s in sentences:
    print(s)
# Out:
# The patient was diagnosed with lung disease.
# The patient was diagnosed with liver disease.
# The patient was diagnosed with heart disease.
# The patient was diagnosed with terminal disease.
# The patient was diagnosed with this disease.

# %%
sentences = fill_mask("Treatment included [MASK] therapy and monitoring.")
for s in sentences:
    print(s)
# Out:
# Treatment included physical therapy and monitoring.
# Treatment included radiation therapy and monitoring.
# Treatment included medical therapy and monitoring.
# Treatment included tailored therapy and monitoring.
# Treatment included supportive therapy and monitoring.

# %%
sentences = fill_mask("The patient presented with [MASK] pain.")
for s in sentences:
    print(s)
# Out:
# The patient presented with abdominal pain.
# The patient presented with chest pain.
# The patient presented with back pain.
# The patient presented with neck pain.
# The patient presented with severe pain.

# %%
# !git clone https://github.com/SaluLink-Design/Authi-1.0-Diabetes.git
# Out:
# Cloning into 'Authi-1.0-Diabetes'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (5/5), 4.91 KiB | 1006.00 KiB/s, done.

# %% [markdown]
# # Task
# Create an AI model called Authi 1.0 that uses ClinicalBERT to analyze clinical notes and identify mentions of Diabetes insipidus, Diabetes mellitus type 1, and Diabetes mellitus type 2. For each identified condition, use the data from "Endocrine CONDITIONS.csv", "Endocrine TREATMENT.csv", and "Endocrine MEDICINE.csv" to provide the corresponding ICD code and description, treatment protocols (diagnostic basket and ongoing management basket with procedure/test details), and medicine information (CDA details for different plans, medicine class, active ingredient, and medicine name/strength).

# %% [markdown]
# ## Load data
#
# ### Subtask:
# Load the three CSV files (`Endocrine CONDITIONS.csv`, `Endocrine MEDICINE.csv`, and `Endocrine TREATMENT.csv`) into pandas DataFrames.

# %% [markdown]
# **Reasoning**:
# The subtask is to load three CSV files into pandas DataFrames. This requires importing the pandas library and then using the `read_csv` function for each file.

# %%
import pandas as pd

conditions_df = pd.read_csv('Authi-1.0-Diabetes/Endocrine CONDITIONS.csv')
medicine_df = pd.read_csv('Authi-1.0-Diabetes/Endocrine MEDICINE.csv')
treatment_df = pd.read_csv('Authi-1.0-Diabetes/Endocrine TREATMENT.csv')

display(conditions_df.head())
display(medicine_df.head())
display(treatment_df.head())
# Out:
#          CHRONIC CONDITIONS ICD-CODE  \
# 0        Diabetes Insipidus    E23.2
# 1        Diabetes Insipidus    N25.1
# 2  Diabetes Mellitus Type 1    G59.0
# 3  Diabetes Mellitus Type 1    G63.2
# 4  Diabetes Mellitus Type 1    E10.0
#
#                                 ICD-CODE Description
# 0                                 Diabetes insipidus
# 1                     Nephrogenic diabetes insipidus
# 2  Diabetic mononeuropathy (E10-E14+ with common ...
# 3  Diabetic polyneuropathy (E10-E14+ with common ...
# 4      Insulin-dependent diabetes mellitus with coma
#   CHRONIC DISEASE LIST CONDITION CDA FOR CORE, PRIORITY AND SAVER PLANS  \
# 0             Diabetes Insipidus                                 R1 500
# 1             Diabetes Insipidus                                 R1 500
# 2       Diabetes Mellitus Type 1                               R 440.00
# 3       Diabetes Mellitus Type 1                               R 440.00
# 4       Diabetes Mellitus Type 1                                R 30.00
#
#   CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS  \
# 0                                    R1 750
# 1                                    R1 750
# 2                                  R 440.00
# 3                                  R 440.00
# 4                                   R 35.00
#
#                                       MEDICINE CLASS     ACTIVE INGREDIENT  \
# 0  Posterior pituitary hormones: Vasopressin and ...          Desmopressin
# 1  Posterior pituitary hormones: Vasopressin and ...          Desmopressin
# 2         Anti-diabetic agents: Long-acting Insulins       Insulin Detemir
# 3         Anti-diabetic agents: Long-acting Insulins      Insulin Glargine
# 4                            Aspirin: Cardiovascular  Acetylsalicylic acid
#
#                           MEDICINE NAME AND STRENGTH
# 0  Ddavp nasal spray 5ml                         ...
# 1  Minirin melt                    60mcg; 120mcg;...
# 2                 Levemir - pre-filled cartridge 3ml
# 3                          Optisulin - cartridge 3ml
# 4  Aspirin 100 Clicks                            ...
#                   CONDITION              DIAGNOSTIC BASKET  \
# 0                       NaN  PROCEDURE OR TEST DESCRIPTION
# 1        Diabetes Insipidus                     U & E only
# 2        Diabetes Insipidus                     Creatinine
# 3        Diabetes Insipidus     Osmolality: Serum or urine
# 4  Diabetes Mellitus Type 1       ECG –\nElectrocardiogram
#
#       DIAGNOSTIC BASKET.1                     DIAGNOSTIC BASKET.2  \
# 0  PROCEDURE OR TEST CODE  NUMBER OF PROCEDURES OR TESTS WE COVER
# 1                    4171                                       1
# 2  4032 or\n4221 or\n4223                                       1
# 3                    4093                                       1
# 4  1232 or\n1233 or\n1236                                       1
#
#        ONGOING MANAGEMENT BASKET ONGOING MANAGEMENT BASKET.1  \
# 0  PROCEDURE OR TEST DESCRIPTION      PROCEDURE OR TEST CODE
# 1                     U & E only                        4171
# 2                     Creatinine      4032 or\n4221 or\n4223
# 3     Osmolality: Serum or urine                        4093
# 4       ECG –\nElectrocardiogram      1232 or\n1233 or\n1236
#
#               ONGOING MANAGEMENT BASKET.2  \
# 0  NUMBER OF PROCEDURES OR TESTS WE COVER
# 1                                       3
# 2                                       3
# 3                                       1
# 4                                       1
#
#                    ONGOING MANAGEMENT BASKET.3
# 0     NUMBER OF SPECIALISTS WE COVER EACH YEAR
# 1                                            1
# 2                                            1
# 3                                            1
# 4  1 (Ophthal- mologist)\n4 (Other Specialist)

# %% [markdown]
# ## Explore data
#
# ### Subtask:
# Examine the structure and content of each DataFrame to understand the available information and how they relate to each other and the user requirements.

# %% [markdown]
# **Reasoning**:
# Display the column names and data types of each DataFrame and the first few rows to understand the structure and content.

# %%
conditions_df.info()
display(conditions_df.head())

medicine_df.info()
display(medicine_df.head())

treatment_df.info()
display(treatment_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CHRONIC CONDITIONS    129 non-null    object
#  1   ICD-CODE              129 non-null    object
#  2   ICD-CODE Description  129 non-null    object
# dtypes: object(3)
# memory usage: 3.2+ KB
#          CHRONIC CONDITIONS ICD-CODE  \
# 0        Diabetes Insipidus    E23.2
# 1        Diabetes Insipidus    N25.1
# 2  Diabetes Mellitus Type 1    G59.0
# 3  Diabetes Mellitus Type 1    G63.2
# 4  Diabetes Mellitus Type 1    E10.0
#
#                                 ICD-CODE Description
# 0                                 Diabetes insipidus
# 1                     Nephrogenic diabetes insipidus
# 2  Diabetic mononeuropathy (E10-E14+ with common ...
# 3  Diabetic polyneuropathy (E10-E14+ with common ...
# 4      Insulin-dependent diabetes mellitus with coma
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 6 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   CHRONIC DISEASE LIST CONDITION             124 non-null    object
#  1   CDA FOR CORE, PRIORITY AND SAVER PLANS     124 non-null    object
#  2   CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS  124 non-null    object
#  3   MEDICINE CLASS                             124 non-null    object
#  4   ACTIVE INGREDIENT                          124 non-null    object
#  5   MEDICINE NAME AND STRENGTH                 123 non-null    object
# dtypes: object(6)
# memory usage: 5.9+ KB
#   CHRONIC DISEASE LIST CONDITION CDA FOR CORE, PRIORITY AND SAVER PLANS  \
# 0             Diabetes Insipidus                                 R1 500
# 1             Diabetes Insipidus                                 R1 500
# 2       Diabetes Mellitus Type 1                               R 440.00
# 3       Diabetes Mellitus Type 1                               R 440.00
# 4       Diabetes Mellitus Type 1                                R 30.00
#
#   CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS  \
# 0                                    R1 750
# 1                                    R1 750
# 2                                  R 440.00
# 3                                  R 440.00
# 4                                   R 35.00
#
#                                       MEDICINE CLASS     ACTIVE INGREDIENT  \
# 0  Posterior pituitary hormones: Vasopressin and ...          Desmopressin
# 1  Posterior pituitary hormones: Vasopressin and ...          Desmopressin
# 2         Anti-diabetic agents: Long-acting Insulins       Insulin Detemir
# 3         Anti-diabetic agents: Long-acting Insulins      Insulin Glargine
# 4                            Aspirin: Cardiovascular  Acetylsalicylic acid
#
#                           MEDICINE NAME AND STRENGTH
# 0  Ddavp nasal spray 5ml                         ...
# 1  Minirin melt                    60mcg; 120mcg;...
# 2                 Levemir - pre-filled cartridge 3ml
# 3                          Optisulin - cartridge 3ml
# 4  Aspirin 100 Clicks                            ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CONDITION                    38 non-null     object
#  1   DIAGNOSTIC BASKET            39 non-null     object
#  2   DIAGNOSTIC BASKET.1          39 non-null     object
#  3   DIAGNOSTIC BASKET.2          39 non-null     object
#  4   ONGOING MANAGEMENT BASKET    39 non-null     object
#  5   ONGOING MANAGEMENT BASKET.1  39 non-null     object
#  6   ONGOING MANAGEMENT BASKET.2  39 non-null     object
#  7   ONGOING MANAGEMENT BASKET.3  39 non-null     object
# dtypes: object(8)
# memory usage: 2.6+ KB
#                   CONDITION              DIAGNOSTIC BASKET  \
# 0                       NaN  PROCEDURE OR TEST DESCRIPTION
# 1        Diabetes Insipidus                     U & E only
# 2        Diabetes Insipidus                     Creatinine
# 3        Diabetes Insipidus     Osmolality: Serum or urine
# 4  Diabetes Mellitus Type 1       ECG –\nElectrocardiogram
#
#       DIAGNOSTIC BASKET.1                     DIAGNOSTIC BASKET.2  \
# 0  PROCEDURE OR TEST CODE  NUMBER OF PROCEDURES OR TESTS WE COVER
# 1                    4171                                       1
# 2  4032 or\n4221 or\n4223                                       1
# 3                    4093                                       1
# 4  1232 or\n1233 or\n1236                                       1
#
#        ONGOING MANAGEMENT BASKET ONGOING MANAGEMENT BASKET.1  \
# 0  PROCEDURE OR TEST DESCRIPTION      PROCEDURE OR TEST CODE
# 1                     U & E only                        4171
# 2                     Creatinine      4032 or\n4221 or\n4223
# 3     Osmolality: Serum or urine                        4093
# 4       ECG –\nElectrocardiogram      1232 or\n1233 or\n1236
#
#               ONGOING MANAGEMENT BASKET.2  \
# 0  NUMBER OF PROCEDURES OR TESTS WE COVER
# 1                                       3
# 2                                       3
# 3                                       1
# 4                                       1
#
#                    ONGOING MANAGEMENT BASKET.3
# 0     NUMBER OF SPECIALISTS WE COVER EACH YEAR
# 1                                            1
# 2                                            1
# 3                                            1
# 4  1 (Ophthal- mologist)\n4 (Other Specialist)

# %% [markdown]
# **Reasoning**:
# Examine the unique values in key columns for joining or mapping and look for potential data quality issues.

# %%
print("Unique conditions in conditions_df:")
print(conditions_df['CHRONIC CONDITIONS'].unique())

print("\nUnique conditions in medicine_df:")
print(medicine_df['CHRONIC DISEASE LIST CONDITION'].unique())

print("\nUnique conditions in treatment_df:")
print(treatment_df['CONDITION'].unique())

print("\nMissing values in medicine_df:")
print(medicine_df.isnull().sum())

print("\nMissing values in treatment_df:")
print(treatment_df.isnull().sum())
# Out:
# Unique conditions in conditions_df:
# ['Diabetes Insipidus' 'Diabetes Mellitus Type 1'
#  'Diabetes Mellitus Type 2']
#
# Unique conditions in medicine_df:
# ['Diabetes Insipidus' 'Diabetes Mellitus Type 1'
#  'Diabetes Mellitus Type 2']
#
# Unique conditions in treatment_df:
# [nan 'Diabetes Insipidus' 'Diabetes Mellitus Type 1'
#  'Diabetes Mellitus Type 2']
#
# Missing values in medicine_df:
# CHRONIC DISEASE LIST CONDITION               0
# CDA FOR CORE, PRIORITY AND SAVER PLANS       0
# CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS    0
# MEDICINE CLASS                               0
# ACTIVE INGREDIENT                            0
# MEDICINE NAME AND STRENGTH                   1
# dtype: int64
#
# Missing values in treatment_df:
# CONDITION                      1
# DIAGNOSTIC BASKET              0
# DIAGNOSTIC BASKET.1            0
# DIAGNOSTIC BASKET.2            0
# ONGOING MANAGEMENT BASKET      0
# ONGOING MANAGEMENT BASKET.1    0
# ONGOING MANAGEMENT BASKET.2    0
# ONGOING MANAGEMENT BASKET.3    0
# dtype: int64

# %% [markdown]
# ## Integrate clinicalbert
#
# ### Subtask:
# Develop a method to process clinical notes using the loaded ClinicalBERT model to identify mentions of the specified diabetes conditions.

# %% [markdown]
# **Reasoning**:
# Define the function `identify_diabetes_mentions` to identify mentions of the specified diabetes conditions in a given clinical note.

# %%
def identify_diabetes_mentions(clinical_note):
    """
    Identifies mentions of specified diabetes conditions in a clinical note.

    Args:
        clinical_note (str): The clinical note to analyze.

    Returns:
        list: A list of identified diabetes conditions.
    """
    diabetes_conditions = ["Diabetes Insipidus", "Diabetes Mellitus Type 1", "Diabetes Mellitus Type 2"]
    identified_conditions = []
    note_lower = clinical_note.lower()

    for condition in diabetes_conditions:
        if condition.lower() in note_lower:
            identified_conditions.append(condition)

    return identified_conditions

# %% [markdown]
# **Reasoning**:
# Test the `identify_diabetes_mentions` function with example clinical notes to ensure it correctly identifies the specified diabetes conditions.

# %%
# Test cases
note1 = "The patient has a history of Diabetes Mellitus Type 2 and is on medication."
note2 = "Diagnosed with Diabetes Insipidus last year. Requires Desmopressin."
note3 = "Assessment reveals symptoms consistent with Diabetes Mellitus Type 1."
note4 = "Patient presents with chest pain, no mention of diabetes."

print(f"Note 1: {identify_diabetes_mentions(note1)}")
print(f"Note 2: {identify_diabetes_mentians(note2)}")
print(f"Note 3: {identify_diabetes_mentions(note3)}")
print(f"Note 4: {identify_diabetes_mentions(note4)}")
# Out:
# Note 1: ['Diabetes Mellitus Type 2']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2511763170.py in <cell line: 0>()
#       6
#       7 print(f"Note 1: {identify_diabetes_mentions(note1)}")
# ----> 8 print(f"Note 2: {identify_diabetes_mentians(note2)}")
#       9 print(f"Note 3: {identify_diabetes_mentions(note3)}")
#      10 print(f"Note 4: {identify_diabetes_mentions(note4)}")
#
# NameError: name 'identify_diabetes_mentians' is not defined

# %% [markdown]
# **Reasoning**:
# Correct the typo in the function call in the test case.

# %%
# Test cases
note1 = "The patient has a history of Diabetes Mellitus Type 2 and is on medication."
note2 = "Diagnosed with Diabetes Insipidus last year. Requires Desmopressin."
note3 = "Assessment reveals symptoms consistent with Diabetes Mellitus Type 1."
note4 = "Patient presents with chest pain, no mention of diabetes."

print(f"Note 1: {identify_diabetes_mentions(note1)}")
print(f"Note 2: {identify_diabetes_mentions(note2)}")
print(f"Note 3: {identify_diabetes_mentions(note3)}")
print(f"Note 4: {identify_diabetes_mentions(note4)}")
# Out:
# Note 1: ['Diabetes Mellitus Type 2']
# Note 2: ['Diabetes Insipidus']
# Note 3: ['Diabetes Mellitus Type 1']
# Note 4: []

# %% [markdown]
# ## Map conditions to data
#
# ### Subtask:
# Create a mechanism to map the identified conditions from ClinicalBERT to the relevant information (ICD codes, descriptions, treatments, and medicines) in the loaded DataFrames.

# %% [markdown]
# **Reasoning**:
# Define a function to map identified conditions to relevant information from the dataframes.

# %%
def get_condition_details(identified_conditions):
    """
    Maps identified diabetes conditions to relevant information from the dataframes.

    Args:
        identified_conditions (list): A list of identified diabetes conditions.

    Returns:
        list: A list of dictionaries, each containing details for an identified condition.
    """
    condition_details = []

    for condition in identified_conditions:
        condition_info = {"condition": condition}

        # Search in conditions_df
        condition_row = conditions_df[conditions_df['CHRONIC CONDITIONS'] == condition]
        if not condition_row.empty:
            condition_info["icd_code"] = condition_row['ICD-CODE'].tolist()
            condition_info["icd_description"] = condition_row['ICD-CODE Description'].tolist()

        # Search in treatment_df
        treatment_rows = treatment_df[treatment_df['CONDITION'] == condition]
        if not treatment_rows.empty:
            condition_info["diagnostic_basket"] = treatment_rows[['DIAGNOSTIC BASKET', 'DIAGNOSTIC BASKET.1', 'DIAGNOSTIC BASKET.2']].to_dict(orient='records')
            condition_info["ongoing_management_basket"] = treatment_rows[['ONGOING MANAGEMENT BASKET', 'ONGOING MANAGEMENT BASKET.1', 'ONGOING MANAGEMENT BASKET.2', 'ONGOING MANAGEMENT BASKET.3']].to_dict(orient='records')


        # Search in medicine_df
        medicine_rows = medicine_df[medicine_df['CHRONIC DISEASE LIST CONDITION'] == condition]
        if not medicine_rows.empty:
            condition_info["medicine_info"] = medicine_rows[['CDA FOR CORE, PRIORITY AND SAVER PLANS', 'CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS', 'MEDICINE CLASS', 'ACTIVE INGREDIENT', 'MEDICINE NAME AND STRENGTH']].to_dict(orient='records')

        condition_details.append(condition_info)

    return condition_details

# Test the function with some identified conditions
test_conditions = ["Diabetes Mellitus Type 2", "Diabetes Insipidus"]
details = get_condition_details(test_conditions)
import json
print(json.dumps(details, indent=4))
# Out:
# [
#     {
#         "condition": "Diabetes Mellitus Type 2",
#         "icd_code": [
#             "E11.0",
#             "E11.1",
#             "E11.2+I79.2*",
#             "E11.2+N08.3*",
#             "E11.3+H28.0*",
#             "E11.3+H36.0*",
#             "E11.3+I79.2*",
#             "E11.4+G59.0*",
#             "E11.4+G63.2*",
#             "E11.4+G73.0*",
#             "E11.4+G99.0*",
#             "E11.4+I79.2*",
#             "E11.5",
#             "E11.5+I79.2*",
#             "E11.6",
#             "E11.6+I79.2*",
#             "E11.6+M14.2*",
#             "E11.6+M14.6*",
#             "E11.7",
#             "E11.7+I79.2*",
#             "E11.8",
#             "E11.8+I79.2*",
#             "E11.9",
#             "E11.9+I79.2*",
#             "E12.0",
#             "E12.1",
#             "E12.2+N08.3*",
#             "E12.3+H28.0*",
#             "E12.3+H36.0*",
#             "E12.4+G59.0*",
#             "E12.4+G63.2*",
#             "E12.4+G73.0*",
#             "E12.4+G99.0*",
#             "E12.5",
#             "E12.5+I79.2*",
#             "E12.6",
#             "E12.6+M14.2*",
#             "E12.6+M14.6*",
#             "E12.7",
#             "E12.8",
#             "E12.9",
#             "O24.1",
#             "O24.2",
#             "O24.3"
#         ],
#         "icd_description": [
#             "Non-insulin-dependent diabetes mellitus with coma",
#             "Non-insulin-dependent diabetes mellitus with ketoacidosis",
#             "Non-insulin-dependent diabetes mellitus with renal complications/Peripheral angiopathy in diseases classified elsewhere",
#             "Non-insulin-dependent diabetes mellitus with renal complications/Insulin-dependent diabetic nephropathy, intracapillary glomerulonephrosis, Kimmelstiel-Wilson syndrome",
#             "Non-insulin-dependent diabetes mellitus with ophthalmic complications/ Diabetic cataract",
#             "Non-insulin-dependent diabetes mellitus with ophthalmic complications/ Diabetic retinopathy",
#             "Non-insulin-dependent diabetes mellitus with ophthalmic complications/Peripheral angiopathy in diseases classified elsewhere",
#             "Non-insulin-dependent diabetes mellitus with neurological complications/ Diabetic mononeuropathy",
#             "Non-insulin-dependent diabetes mellitus with neurological complications/ Diabetic polyneuropathy",
#             "Non-insulin-dependent diabetes mellitus with neurological complications/ Diabetic amyotrophy",
#             "Non-insulin-dependent diabetes mellitus with neurological complications/Daibeteic autonomic neuropathy and or Diabetic autonomic polyneuropathy",
#             "Non-insulin-dependent diabetes mellitus with neurological complications/Peripheral angiopathy in diseases classified elsewhere",
#             "Non-insulin-dependent diabetes mellitus with peripheral circulatory complications",
#             "Non-insulin-dependent diabetes mellitus with peripheral circulatory complications/ Diabetic peripheral angiopathy",
#             "Non-insulin-dependent diabetes mellitus with other specified complications",
#             "Non-insulin-dependent diabetes mellitus with other specified complications/Peripheral angiopathy in diseases classified elsewhere",
#             "Non-insulin-dependent diabetes mellitus with other specified complications/Diabetic arthropathy",
#             "Non-insulin-dependent diabetes mellitus with other specified complications/Diabetic neuropathic arthropathyarthropathy",
#             "Non-insulin-dependent diabetes mellitus with multiple complications",
#             "Non-insulin-dependent diabetes mellitus with multiple complications/Peripheral angiopathy in diseases classified elsewhere",
#             "Non-insulin-dependent diabetes mellitus with unspecified complications",
#             "Non-insulin-dependent diabetes mellitus with unspecified complications/Peripheral angiopathy in diseases classified elsewhere",
#             "Non-insulin-dependent diabetes mellitus without complications",
#             "Non-insulin-dependent diabetes mellitus without complications/Peripheral angiopathy in diseases classified elsewhere",
#             "Malnutrition-related diabetes mellitus with coma",
#             "Malnutrition-related diabetes mellitus with ketoacidosis",
#             "Malnutrition-related diabetes mellitus with renal complications/Insulin-dependent diabetic nephropathy, intracapillary glomerulonephrosis, Kimmelstiel-Wilson syndrome",
#             "Malnutrition-related diabetes mellitus with ophthalmic complications/ Diabetic cataract",
#             "Malnutrition-related diabetes mellitus with ophthalmic complications/ Diabetic retinopathy",
#             "Malnutrition-relatedt diabetes mellitus with neurological complications/ Diabetic mononeuropathy",
#             "Malnutrition-relateddiabetes mellitus with neurological complications/ Diabetic polyneuropathy",
#             "Malnutrition-relateddiabetes mellitus with neurological complications/ Diabetic amyotrophy",
#             "Malnutrition-relateddiabetes mellitus with neurological complications/Daibeteic autonomic neuropathy and or Diabetic autonomic polyneuropathy",
#             "Malnutrition-related diabetes mellitus with peripheral circulatory complications",
#             "Malnutrition-related diabetes mellitus with peripheral circulatory complications/ Diabetic peripheral angiopathy",
#             "Malnutrition-related diabetes mellitus with other specified complications",
#             "Malnutrition-related  diabetes mellitus with other specified complications/Diabetic arthropathy",
#             "Malnutrition-related  diabetes mellitus with other specified complications/Diabetic neuropathic arthropathyarthropathy",
#             "Malnutrition-related diabetes mellitus with multiple complications",
#             "Malnutrition-related diabetes mellitus with unspecified complications",
#             "Malnutrition-related diabetes mellitus without complications",
#             "Pre-existing diabetes mellitus, non-insulin-dependent",
#             "Pre-existing malnutrition-related diabetes mellitus",
#             "Pre-existing diabetes mellitus, unspecified"
#         ],
#         "diagnostic_basket": [
#             {
#                 "DIAGNOSTIC BASKET": "ECG \u2013\nElectrocardiogram",
#                 "DIAGNOSTIC BASKET.1": "1232 or\n1233 or\n1236",
#                 "DIAGNOSTIC BASKET.2": "1"
#             },
#             {
#                 "DIAGNOSTIC BASKET": "Microalbuminuria",
#                 "DIAGNOSTIC BASKET.1": "4261 or\n4262",
#                 "DIAGNOSTIC BASKET.2": "1"
#             },
#             {
#                 "DIAGNOSTIC BASKET": "HDL cholesterol",
#                 "DIAGNOSTIC BASKET.1": "4028",
#                 "DIAGNOSTIC BASKET.2": "1"
#             },
#             {
#                 "DIAGNOSTIC BASKET": "Total cholesterol",
#                 "DIAGNOSTIC BASKET.1": "4027",
#                 "DIAGNOSTIC BASKET.2": "1"
#             },
#             {
#                 "DIAGNOSTIC BASKET": "LDL cholesterol",
#                 "DIAGNOSTIC BASKET.1": "4026",
#                 "DIAGNOSTIC BASKET.2": "1"
#             },
#             {
#                 "DIAGNOSTIC BASKET": "Triglycerides",
#                 "DIAGNOSTIC BASKET.1": "4147",
#                 "DIAGNOSTIC BASKET.2": "1"
#             },
#             {
#                 "DIAGNOSTIC BASKET": "Urine analysis (dipstick)",
#                 "DIAGNOSTIC BASKET.1": "4188",
#                 "DIAGNOSTIC BASKET.2": "1"
#             },
#             {
#                 "DIAGNOSTIC BASKET": "U & E only",
#                 "DIAGNOSTIC BASKET.1": "4171",
#                 "DIAGNOSTIC BASKET.2": "1"
#             },
#             {
#                 "DIAGNOSTIC BASKET": "Urine creatinine",
#                 "DIAGNOSTIC BASKET.1": "4221",
#                 "DIAGNOSTIC BASKET.2": "1"
#             },
#             {
#                 "DIAGNOSTIC BASKET": "Glucose \u2013\nrandom/fasting",
#                 "DIAGNOSTIC BASKET.1": "4057",
#                 "DIAGNOSTIC BASKET.2": "1"
#             },
#             {
#                 "DIAGNOSTIC BASKET": "Serum creatinine",
#                 "DIAGNOSTIC BASKET.1": "4032 or\n4223",
#                 "DIAGNOSTIC BASKET.2": "1"
#             },
#             {
#                 "DIAGNOSTIC BASKET": "Two-hour glucose- OGTT",
#                 "DIAGNOSTIC BASKET.1": "4049",
#                 "DIAGNOSTIC BASKET.2": "1"
#             },
#             {
#                 "DIAGNOSTIC BASKET": "Two-hour glucose- OGTT",
#                 "DIAGNOSTIC BASKET.1": "4049",
#                 "DIAGNOSTIC BASKET.2": "1"
#             },
#             {
#                 "DIAGNOSTIC BASKET": "Two-hour glucose- OGTT",
#                 "DIAGNOSTIC BASKET.1": "4049",
#                 "DIAGNOSTIC BASKET.2": "1"
#             },
#             {
#                 "DIAGNOSTIC BASKET": "Two-hour glucose- OGTT",
#                 "DIAGNOSTIC BASKET.1": "4049",
#                 "DIAGNOSTIC BASKET.2": "1"
#             },
#             {
#                 "DIAGNOSTIC BASKET": "Two-hour glucose- OGTT",
#                 "DIAGNOSTIC BASKET.1": "4049",
#                 "DIAGNOSTIC BASKET.2": "1"
#             },
#             {
#                 "DIAGNOSTIC BASKET": "Two-hour glucose- OGTT",
#                 "DIAGNOSTIC BASKET.1": "4049",
#                 "DIAGNOSTIC BASKET.2": "1"
#             }
#         ],
#         "ongoing_management_basket": [
#             {
#                 "ONGOING MANAGEMENT BASKET": "ECG \u2013\nElectrocardiogram",
#                 "ONGOING MANAGEMENT BASKET.1": "1232 or\n1233 or\n1236",
#                 "ONGOING MANAGEMENT BASKET.2": "1",
#                 "ONGOING MANAGEMENT BASKET.3": "1 (Ophthal- mologist)\n1 (Other Specialist)"
#             },
#             {
#                 "ONGOING MANAGEMENT BASKET": "Microalbuminuria",
#                 "ONGOING MANAGEMENT BASKET.1": "4261 or\n4262",
#                 "ONGOING MANAGEMENT BASKET.2": "2",
#                 "ONGOING MANAGEMENT BASKET.3": "1 (Ophthal- mologist)\n1 (Other Specialist)"
#             },
#             {
#                 "ONGOING MANAGEMENT BASKET": "HDL cholesterol",
#                 "ONGOING MANAGEMENT BASKET.1": "4028",
#                 "ONGOING MANAGEMENT BASKET.2": "1",
#                 "ONGOING MANAGEMENT BASKET.3": "1 (Ophthal- mologist)\n1 (Other Specialist)"
#             },
#             {
#                 "ONGOING MANAGEMENT BASKET": "Total cholesterol",
#                 "ONGOING MANAGEMENT BASKET.1": "4027",
#                 "ONGOING MANAGEMENT BASKET.2": "1",
#                 "ONGOING MANAGEMENT BASKET.3": "1 (Ophthal- mologist)\n1 (Other Specialist)"
#             },
#             {
#                 "ONGOING MANAGEMENT BASKET": "LDL cholesterol",
#                 "ONGOING MANAGEMENT BASKET.1": "4026",
#                 "ONGOING MANAGEMENT BASKET.2": "1",
#                 "ONGOING MANAGEMENT BASKET.3": "1 (Ophthal- mologist)\n1 (Other Specialist)"
#             },
#             {
#                 "ONGOING MANAGEMENT BASKET": "Triglycerides",
#                 "ONGOING MANAGEMENT BASKET.1": "4147",
#                 "ONGOING MANAGEMENT BASKET.2": "1",
#                 "ONGOING MANAGEMENT BASKET.3": "1 (Ophthal- mologist)\n1 (Other Specialist)"
#             },
#             {
#                 "ONGOING MANAGEMENT BASKET": "Urine analysis (dipstick)",
#                 "ONGOING MANAGEMENT BASKET.1": "4188",
#                 "ONGOING MANAGEMENT BASKET.2": "4",
#                 "ONGOING MANAGEMENT BASKET.3": "1 (Ophthal- mologist)\n1 (Other Specialist)"
#             },
#             {
#                 "ONGOING MANAGEMENT BASKET": "U & E only",
#                 "ONGOING MANAGEMENT BASKET.1": "4171",
#                 "ONGOING MANAGEMENT BASKET.2": "1",
#                 "ONGOING MANAGEMENT BASKET.3": "1 (Ophthal- mologist)\n1 (Other Specialist)"
#             },
#             {
#                 "ONGOING MANAGEMENT BASKET": "Urine creatinine",
#                 "ONGOING MANAGEMENT BASKET.1": "4221",
#                 "ONGOING MANAGEMENT BASKET.2": "1",
#                 "ONGOING MANAGEMENT BASKET.3": "1 (Ophthal- mologist)\n1 (Other Specialist)"
#             },
#             {
#                 "ONGOING MANAGEMENT BASKET": "HbA1c",
#                 "ONGOING MANAGEMENT BASKET.1": "4064",
#                 "ONGOING MANAGEMENT BASKET.2": "4",
#                 "ONGOING MANAGEMENT BASKET.3": "1 (Ophthal- mologist)\n1 (Other Specialist)"
#             },
#             {
#                 "ONGOING MANAGEMENT BASKET": "Serum creatinine",
#                 "ONGOING MANAGEMENT BASKET.1": "4032 or\n4223",
#                 "ONGOING MANAGEMENT BASKET.2": "1",
#                 "ONGOING MANAGEMENT BASKET.3": "1 (Ophthal- mologist)\n1 (Other Specialist)"
#             },
#             {
#                 "ONGOING MANAGEMENT BASKET": "Tonometry",
#                 "ONGOING MANAGEMENT BASKET.1": "3014",
#                 "ONGOING MANAGEMENT BASKET.2": "1",
#                 "ONGOING MANAGEMENT BASKET.3": "1 (Ophthal- mologist)\n1 (Other Specialist)"
#             },
#             {
#                 "ONGOING MANAGEMENT BASKET": "Basic capital equipped in own rooms by ophthalmologists",
#                 "ONGOING MANAGEMENT BASKET.1": "3009",
#                 "ONGOING MANAGEMENT BASKET.2": "1",
#                 "ONGOING MANAGEMENT BASKET.3": "1 (Ophthal- mologist)\n1 (Other Specialist)"
#             },
#             {
#                 "ONGOING MANAGEMENT BASKET": "Fundus examination",
#                 "ONGOING MANAGEMENT BASKET.1": "3003 or\n3004 or\n3027",
#                 "ONGOING MANAGEMENT BASKET.2": "1",
#                 "ONGOING MANAGEMENT BASKET.3": "1 (Ophthal- mologist)\n1 (Other Specialist)"
#             },
#             {
#                 "ONGOING MANAGEMENT BASKET": "Podiatrist",
#                 "ONGOING MANAGEMENT BASKET.1": "68301 or\n68302 or\n68303 or\n68304 or",
#                 "ONGOING MANAGEMENT BASKET.2": "1",
#                 "ONGOING MANAGEMENT BASKET.3": "1 (Ophthal- mologist)\n1 (Other Specialist)"
#             },
#             {
#                 "ONGOING MANAGEMENT BASKET": "Diabetes Educator",
#                 "ONGOING MANAGEMENT BASKET.1": "DFSC1",
#                 "ONGOING MANAGEMENT BASKET.2": "1",
#                 "ONGOING MANAGEMENT BASKET.3": "1 (Ophthal- mologist)\n1 (Other Specialist)"
#             },
#             {
#                 "ONGOING MANAGEMENT BASKET": "Dietitian",
#                 "ONGOING MANAGEMENT BASKET.1": "84200 or\n84201 or\n84202 or\n84203 or\n84204 or\n84205",
#                 "ONGOING MANAGEMENT BASKET.2": "1",
#                 "ONGOING MANAGEMENT BASKET.3": "1 (Ophthal- mologist)\n1 (Other Specialist)"
#             }
#         ],
#         "medicine_info": [
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a050.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a050.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Biguanides",
#                 "ACTIVE INGREDIENT": "Metformin",
#                 "MEDICINE NAME AND STRENGTH": "Accord Metformin                         500mg; 850mg"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a050.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a050.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Biguanides",
#                 "ACTIVE INGREDIENT": "Metformin",
#                 "MEDICINE NAME AND STRENGTH": "Apex-Metformin                                        500mg"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a050.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a050.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Biguanides",
#                 "ACTIVE INGREDIENT": "Metformin",
#                 "MEDICINE NAME AND STRENGTH": "Bigsens                           500mg; 850mg; 1000mg"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a050.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a050.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Biguanides",
#                 "ACTIVE INGREDIENT": "Metformin",
#                 "MEDICINE NAME AND STRENGTH": "Diamin                                         500mg; 850mg"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a050.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a050.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Biguanides",
#                 "ACTIVE INGREDIENT": "Metformin",
#                 "MEDICINE NAME AND STRENGTH": "Diaphage                        500mg; 850mg; 1000mg"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a050.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a050.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Biguanides",
#                 "ACTIVE INGREDIENT": "Metformin",
#                 "MEDICINE NAME AND STRENGTH": "Gluconorm                                    500mg; 850mg"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a050.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a050.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Biguanides",
#                 "ACTIVE INGREDIENT": "Metformin",
#                 "MEDICINE NAME AND STRENGTH": "Fortese                                                   1000mg"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a050.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a050.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Biguanides",
#                 "ACTIVE INGREDIENT": "Metformin",
#                 "MEDICINE NAME AND STRENGTH": "Mylan Metformin            500mg; 850mg; 1000mg"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a050.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a050.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Biguanides",
#                 "ACTIVE INGREDIENT": "Metformin",
#                 "MEDICINE NAME AND STRENGTH": "Romidab                         500mg; 850mg; 1000mg"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0395.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0400.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Fast-acting Insulins",
#                 "ACTIVE INGREDIENT": "Insulin Aspart",
#                 "MEDICINE NAME AND STRENGTH": "Fiasp - penfill 3ml\n(Only Executive and Comprehensive plans)"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0395.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0400.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Fast-acting Insulins",
#                 "ACTIVE INGREDIENT": "Insulin Aspart",
#                 "MEDICINE NAME AND STRENGTH": "Novorapid - penfill 3ml\n(Not available on KeyCare plans)"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0395.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0400.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Fast-acting Insulins",
#                 "ACTIVE INGREDIENT": "Insulin Glulisine",
#                 "MEDICINE NAME AND STRENGTH": "Apidra - cartridge 3ml"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0700.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0720.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Intermediate-acting or long-acting combined with fast-acting Insulins (Biphasic)",
#                 "ACTIVE INGREDIENT": "Insulin Degludec and Insulin Aspart",
#                 "MEDICINE NAME AND STRENGTH": "Ryzodeg - penfill 3ml\n(Only Executive and Comprehensive plans)"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0700.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0720.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Intermediate-acting or long-acting combined with fast-acting Insulins (Biphasic)",
#                 "ACTIVE INGREDIENT": "Insulin Lispro",
#                 "MEDICINE NAME AND STRENGTH": "Humalog mix 25 - cartridge 3ml"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0700.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0720.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Intermediate-acting or long-acting combined with fast-acting Insulins (Biphasic)",
#                 "ACTIVE INGREDIENT": "Insulin Lispro",
#                 "MEDICINE NAME AND STRENGTH": "Humalog mix 50 - cartridge 3ml"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0440.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0440.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Long-acting Insulins",
#                 "ACTIVE INGREDIENT": "Insulin Detemir",
#                 "MEDICINE NAME AND STRENGTH": "Levemir - pre-filled cartridge 3ml"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0440.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0440.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Long-acting Insulins",
#                 "ACTIVE INGREDIENT": "Insulin Glargine",
#                 "MEDICINE NAME AND STRENGTH": "Optisulin - cartridge 3ml"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0125.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0125.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Sulfonamides, urea derivatives",
#                 "ACTIVE INGREDIENT": "Gliclazide",
#                 "MEDICINE NAME AND STRENGTH": "Diaran MR *                                               60mg"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0125.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0125.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Sulfonamides, urea derivatives",
#                 "ACTIVE INGREDIENT": "Gliclazide",
#                 "MEDICINE NAME AND STRENGTH": "Dynacaz MR                           30mg; 60mg; 90mg"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0125.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0125.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Sulfonamides, urea derivatives",
#                 "ACTIVE INGREDIENT": "Gliclazide",
#                 "MEDICINE NAME AND STRENGTH": "Gliclazide MR Austell                                   60mg"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0125.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0125.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Sulfonamides, urea derivatives",
#                 "ACTIVE INGREDIENT": "Gliclazide",
#                 "MEDICINE NAME AND STRENGTH": "Gliclazide Unicorn MR                                 30mg"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0125.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0125.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Sulfonamides, urea derivatives",
#                 "ACTIVE INGREDIENT": "Gliclazide",
#                 "MEDICINE NAME AND STRENGTH": "Gluctam MR                                                60mg"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0125.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0125.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Sulfonamides, urea derivatives",
#                 "ACTIVE INGREDIENT": "Gliclazide",
#                 "MEDICINE NAME AND STRENGTH": "Glyzid MR                                         30mg; 60mg"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0200.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0215.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Thiazolidinediones",
#                 "ACTIVE INGREDIENT": "Pioglitazone",
#                 "MEDICINE NAME AND STRENGTH": "Cipla-Pioglitazone                             15mg; 30mg"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0200.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0215.00",
#                 "MEDICINE CLASS": "Anti-diabetic agents: Thiazolidinediones",
#                 "ACTIVE INGREDIENT": "Pioglitazone",
#                 "MEDICINE NAME AND STRENGTH": "Pioglitazone hydrochloride Macleods 15mg; 30mg"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a030.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a035.00",
#                 "MEDICINE CLASS": "Aspirin: Cardiovascular",
#                 "ACTIVE INGREDIENT": "Acetylsalicylic acid",
#                 "MEDICINE NAME AND STRENGTH": "Aspirin 100 Clicks                                      100mg"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a030.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a035.00",
#                 "MEDICINE CLASS": "Aspirin: Cardiovascular",
#                 "ACTIVE INGREDIENT": "Acetylsalicylic acid",
#                 "MEDICINE NAME AND STRENGTH": "Coprin                                                      100mg"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a030.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a035.00",
#                 "MEDICINE CLASS": "Aspirin: Cardiovascular",
#                 "ACTIVE INGREDIENT": "Acetylsalicylic acid",
#                 "MEDICINE NAME AND STRENGTH": "Myoprin *                                                 100mg\n(Not available on KeyCare plans)"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a030.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a035.00",
#                 "MEDICINE CLASS": "Aspirin: Cardiovascular",
#                 "ACTIVE INGREDIENT": "Acetylsalicylic acid",
#                 "MEDICINE NAME AND STRENGTH": "Trinprin                                                    100mg"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0200.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0200.00",
#                 "MEDICINE CLASS": "Blood glucose monitoring agents",
#                 "ACTIVE INGREDIENT": "Glucose strips",
#                 "MEDICINE NAME AND STRENGTH": "Accu check test strip glucose active\n(Not available on KeyCare plans)"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0200.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0200.00",
#                 "MEDICINE CLASS": "Blood glucose monitoring agents",
#                 "ACTIVE INGREDIENT": "Glucose strips",
#                 "MEDICINE NAME AND STRENGTH": "Accu check test strip glucose instant\n(Not available on KeyCare plans)"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0200.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0200.00",
#                 "MEDICINE CLASS": "Blood glucose monitoring agents",
#                 "ACTIVE INGREDIENT": "Glucose strips",
#                 "MEDICINE NAME AND STRENGTH": "Contour plus blood glucose test strips\n(Not available on KeyCare plans)"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0200.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0200.00",
#                 "MEDICINE CLASS": "Blood glucose monitoring agents",
#                 "ACTIVE INGREDIENT": "Glucose strips",
#                 "MEDICINE NAME AND STRENGTH": "Contour ts blood glucose test strips\n(Not available on KeyCare plans)"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0200.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0200.00",
#                 "MEDICINE CLASS": "Blood glucose monitoring agents",
#                 "ACTIVE INGREDIENT": "Glucose strips",
#                 "MEDICINE NAME AND STRENGTH": "Glucocheck evolve test strip"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0200.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0200.00",
#                 "MEDICINE CLASS": "Blood glucose monitoring agents",
#                 "ACTIVE INGREDIENT": "Glucose strips",
#                 "MEDICINE NAME AND STRENGTH": "Glucocheck key test strip"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0200.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0200.00",
#                 "MEDICINE CLASS": "Blood glucose monitoring agents",
#                 "ACTIVE INGREDIENT": "Glucose strips",
#                 "MEDICINE NAME AND STRENGTH": "On call plus blood glucose strips"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0200.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0200.00",
#                 "MEDICINE CLASS": "Blood glucose monitoring agents",
#                 "ACTIVE INGREDIENT": "Glucose strips",
#                 "MEDICINE NAME AND STRENGTH": "On call sure blood glucose test strips"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0200.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0200.00",
#                 "MEDICINE CLASS": "Blood glucose monitoring agents",
#                 "ACTIVE INGREDIENT": "Glucose strips",
#                 "MEDICINE NAME AND STRENGTH": "Onetouch select plus test strips"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0200.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0200.00",
#                 "MEDICINE CLASS": "Blood glucose monitoring agents",
#                 "ACTIVE INGREDIENT": "Glucose strips",
#                 "MEDICINE NAME AND STRENGTH": "Test strip blood glucose clicks bionime gs550"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0200.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0200.00",
#                 "MEDICINE CLASS": "Blood glucose monitoring agents",
#                 "ACTIVE INGREDIENT": "Glucose strips",
#                 "MEDICINE NAME AND STRENGTH": "Test strip freestyle optium glucose\n(Not available on KeyCare plans)"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0200.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0200.00",
#                 "MEDICINE CLASS": "Blood glucose monitoring agents",
#                 "ACTIVE INGREDIENT": "Glucose strips",
#                 "MEDICINE NAME AND STRENGTH": "Test strip glucocheck connekt\n(Only Executive and Comprehensive plans)"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0200.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0200.00",
#                 "MEDICINE CLASS": "Blood glucose monitoring agents",
#                 "ACTIVE INGREDIENT": "Glucose strips",
#                 "MEDICINE NAME AND STRENGTH": "Test strip glucose blood fora 6\n(Not available on KeyCare plans)"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0200.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0200.00",
#                 "MEDICINE CLASS": "Blood glucose monitoring agents",
#                 "ACTIVE INGREDIENT": "Glucose strips",
#                 "MEDICINE NAME AND STRENGTH": "Test strip glucose caresens n 29g"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0200.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0200.00",
#                 "MEDICINE CLASS": "Blood glucose monitoring agents",
#                 "ACTIVE INGREDIENT": "Glucose strips",
#                 "MEDICINE NAME AND STRENGTH": "Test strip glucose fora diamond blood"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0200.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0200.00",
#                 "MEDICINE CLASS": "Blood glucose monitoring agents",
#                 "ACTIVE INGREDIENT": "Glucose strips",
#                 "MEDICINE NAME AND STRENGTH": "Test strip glucose vivachek ino"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Lancets",
#                 "MEDICINE NAME AND STRENGTH": "Lancet blood collection needle loris"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Lancets",
#                 "MEDICINE NAME AND STRENGTH": "Lancet fora collection needle sterile 30g"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Lancets",
#                 "MEDICINE NAME AND STRENGTH": "Lancet fora tender needle sterile 33g"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Lancets",
#                 "MEDICINE NAME AND STRENGTH": "Lancet freestyle test"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Lancets",
#                 "MEDICINE NAME AND STRENGTH": "Lancet glucocheck novicheck"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Lancets",
#                 "MEDICINE NAME AND STRENGTH": "Lancet solus v2"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Lancets",
#                 "MEDICINE NAME AND STRENGTH": "Lancet unilet sterile 28g"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Lancets",
#                 "MEDICINE NAME AND STRENGTH": "Lancet unilet sterile 4cm x 6cm x 7.5cm 28g"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Lancets",
#                 "MEDICINE NAME AND STRENGTH": "Microlet lancet"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Needles",
#                 "MEDICINE NAME AND STRENGTH": "BD micro fine plus pen needle 30g 8mm"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Needles",
#                 "MEDICINE NAME AND STRENGTH": "BD micro fine plus pen needle 31g"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Needles",
#                 "MEDICINE NAME AND STRENGTH": "BD micro fine plus pen needle 32g 4mm"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Needles",
#                 "MEDICINE NAME AND STRENGTH": "Droplet pen needle 8mm 31g"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Needles",
#                 "MEDICINE NAME AND STRENGTH": "Needle insulin fora pen 31g 5mm"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Needles",
#                 "MEDICINE NAME AND STRENGTH": "Needle insulin fora pen 31g 8mm"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Needles",
#                 "MEDICINE NAME AND STRENGTH": "Needle insulin fora pen 32g 4mm"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Needles",
#                 "MEDICINE NAME AND STRENGTH": "Needle insulin fora pen 32g 6mm"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Needles",
#                 "MEDICINE NAME AND STRENGTH": "Needle insulin pen verifine 4mmx10cmx15cm 32g"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Needles",
#                 "MEDICINE NAME AND STRENGTH": "Needle insulin pen verifine 4mmx10cmx15cm 33g"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Needles",
#                 "MEDICINE NAME AND STRENGTH": "Needle novofine"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Syringes",
#                 "MEDICINE NAME AND STRENGTH": "Syringe insulin 1.0ml with 27g needle"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Syringes",
#                 "MEDICINE NAME AND STRENGTH": "Syringe insulin bd microfine 12.7mm 1ml 9g"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Syringes",
#                 "MEDICINE NAME AND STRENGTH": "Syringe insulin bd microfine 1ml 8mm 30g"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R\u00a0350.00",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R\u00a0350.00",
#                 "MEDICINE CLASS": "Surgical item",
#                 "ACTIVE INGREDIENT": "Syringes",
#                 "MEDICINE NAME AND STRENGTH": "Syringe insulin bd microfine 8mm demi 0.3ml 30g"
#             }
#         ]
#     },
#     {
#         "condition": "Diabetes Insipidus",
#         "icd_code": [
#             "E23.2",
#             "N25.1"
#         ],
#         "icd_description": [
#             "Diabetes insipidus",
#             "Nephrogenic diabetes insipidus"
#         ],
#         "diagnostic_basket": [
#             {
#                 "DIAGNOSTIC BASKET": "U & E only",
#                 "DIAGNOSTIC BASKET.1": "4171",
#                 "DIAGNOSTIC BASKET.2": "1"
#             },
#             {
#                 "DIAGNOSTIC BASKET": "Creatinine",
#                 "DIAGNOSTIC BASKET.1": "4032 or\n4221 or\n4223",
#                 "DIAGNOSTIC BASKET.2": "1"
#             },
#             {
#                 "DIAGNOSTIC BASKET": "Osmolality: Serum or urine",
#                 "DIAGNOSTIC BASKET.1": "4093",
#                 "DIAGNOSTIC BASKET.2": "1"
#             }
#         ],
#         "ongoing_management_basket": [
#             {
#                 "ONGOING MANAGEMENT BASKET": "U & E only",
#                 "ONGOING MANAGEMENT BASKET.1": "4171",
#                 "ONGOING MANAGEMENT BASKET.2": "3",
#                 "ONGOING MANAGEMENT BASKET.3": "1"
#             },
#             {
#                 "ONGOING MANAGEMENT BASKET": "Creatinine",
#                 "ONGOING MANAGEMENT BASKET.1": "4032 or\n4221 or\n4223",
#                 "ONGOING MANAGEMENT BASKET.2": "3",
#                 "ONGOING MANAGEMENT BASKET.3": "1"
#             },
#             {
#                 "ONGOING MANAGEMENT BASKET": "Osmolality: Serum or urine",
#                 "ONGOING MANAGEMENT BASKET.1": "4093",
#                 "ONGOING MANAGEMENT BASKET.2": "1",
#                 "ONGOING MANAGEMENT BASKET.3": "1"
#             }
#         ],
#         "medicine_info": [
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R1 500",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R1 750",
#                 "MEDICINE CLASS": "Posterior pituitary hormones: Vasopressin and analogues",
#                 "ACTIVE INGREDIENT": "Desmopressin",
#                 "MEDICINE NAME AND STRENGTH": "Ddavp nasal spray 5ml                         0.1mg/1ml"
#             },
#             {
#                 "CDA FOR CORE, PRIORITY AND SAVER PLANS": "R1 500",
#                 "CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS": "R1 750",
#                 "MEDICINE CLASS": "Posterior pituitary hormones: Vasopressin and analogues",
#                 "ACTIVE INGREDIENT": "Desmopressin",
#                 "MEDICINE NAME AND STRENGTH": "Minirin melt                    60mcg; 120mcg; 240mcg"
#             }
#         ]
#     }
# ]

# %% [markdown]
# ## Generate output
#
# ### Subtask:
# Based on the identified conditions and the mapped data, generate a structured output that provides relevant information about the condition, treatment protocols, and medicine details.

# %% [markdown]
# **Reasoning**:
# Define the `generate_report` function to format the condition details into a human-readable string and then call it with sample data.

# %%
def generate_report(condition_details):
    """
    Generates a human-readable report from condition details.

    Args:
        condition_details (list): A list of dictionaries, each containing details for an identified condition.

    Returns:
        str: A formatted string containing the report.
    """
    report = ""
    for detail in condition_details:
        report += f"Condition: {detail.get('condition', 'N/A')}\n"

        # ICD Information
        icd_codes = detail.get('icd_code', [])
        icd_descriptions = detail.get('icd_description', [])
        if icd_codes:
            report += "  ICD Codes and Descriptions:\n"
            for code, desc in zip(icd_codes, icd_descriptions):
                report += f"    - Code: {code}, Description: {desc}\n"
        else:
            report += "  ICD Information: N/A\n"

        # Diagnostic Basket
        diagnostic_basket = detail.get('diagnostic_basket', [])
        if diagnostic_basket:
            report += "  Diagnostic Basket:\n"
            for item in diagnostic_basket:
                report += f"    - Procedure/Test: {item.get('DIAGNOSTIC BASKET', 'N/A')}, Code: {item.get('DIAGNOSTIC BASKET.1', 'N/A')}, Number Covered: {item.get('DIAGNOSTIC BASKET.2', 'N/A')}\n"
        else:
            report += "  Diagnostic Basket: N/A\n"

        # Ongoing Management Basket
        ongoing_management_basket = detail.get('ongoing_management_basket', [])
        if ongoing_management_basket:
            report += "  Ongoing Management Basket:\n"
            for item in ongoing_management_basket:
                report += f"    - Procedure/Test: {item.get('ONGOING MANAGEMENT BASKET', 'N/A')}, Code: {item.get('ONGOING MANAGEMENT BASKET.1', 'N/A')}, Number Covered (Tests): {item.get('ONGOING MANAGEMENT BASKET.2', 'N/A')}, Number Covered (Specialists): {item.get('ONGOING MANAGEMENT BASKET.3', 'N/A')}\n"
        else:
            report += "  Ongoing Management Basket: N/A\n"

        # Medicine Information
        medicine_info = detail.get('medicine_info', [])
        if medicine_info:
            report += "  Medicine Information:\n"
            for item in medicine_info:
                report += f"    - CDA Core/Priority/Saver: {item.get('CDA FOR CORE, PRIORITY AND SAVER PLANS', 'N/A')}, CDA Executive/Comprehensive: {item.get('CDA FOR EXECUTIVE AND COMPREHENSIVE PLANS', 'N/A')}, Class: {item.get('MEDICINE CLASS', 'N/A')}, Active Ingredient: {item.get('ACTIVE INGREDIENT', 'N/A')}, Name/Strength: {item.get('MEDICINE NAME AND STRENGTH', 'N/A')}\n"
        else:
            report += "  Medicine Information: N/A\n"

        report += "\n" # Add a newline between conditions

    return report

# Test the function with sample identified conditions
test_conditions = ["Diabetes Mellitus Type 2", "Diabetes Insipidus"]
details = get_condition_details(test_conditions)
report_output = generate_report(details)
print(report_output)
# Out:
# Condition: Diabetes Mellitus Type 2
#   ICD Codes and Descriptions:
#     - Code: E11.0, Description: Non-insulin-dependent diabetes mellitus with coma
#     - Code: E11.1, Description: Non-insulin-dependent diabetes mellitus with ketoacidosis
#     - Code: E11.2+I79.2*, Description: Non-insulin-dependent diabetes mellitus with renal complications/Peripheral angiopathy in diseases classified elsewhere
#     - Code: E11.2+N08.3*, Description: Non-insulin-dependent diabetes mellitus with renal complications/Insulin-dependent diabetic nephropathy, intracapillary glomerulonephrosis, Kimmelstiel-Wilson syndrome
#     - Code: E11.3+H28.0*, Description: Non-insulin-dependent diabetes mellitus with ophthalmic complications/ Diabetic cataract
#     - Code: E11.3+H36.0*, Description: Non-insulin-dependent diabetes mellitus with ophthalmic complications/ Diabetic retinopathy
#     - Code: E11.3+I79.2*, Description: Non-insulin-dependent diabetes mellitus with ophthalmic complications/Peripheral angiopathy in diseases classified elsewhere
#     - Code: E11.4+G59.0*, Description: Non-insulin-dependent diabetes mellitus with neurological complications/ Diabetic mononeuropathy
#     - Code: E11.4+G63.2*, Description: Non-insulin-dependent diabetes mellitus with neurological complications/ Diabetic polyneuropathy
#     - Code: E11.4+G73.0*, Description: Non-insulin-dependent diabetes mellitus with neurological complications/ Diabetic amyotrophy
#     - Code: E11.4+G99.0*, Description: Non-insulin-dependent diabetes mellitus with neurological complications/Daibeteic autonomic neuropathy and or Diabetic autonomic polyneuropathy
#     - Code: E11.4+I79.2*, Description: Non-insulin-dependent diabetes mellitus with neurological complications/Peripheral angiopathy in diseases classified elsewhere
#     - Code: E11.5, Description: Non-insulin-dependent diabetes mellitus with peripheral circulatory complications
#     - Code: E11.5+I79.2*, Description: Non-insulin-dependent diabetes mellitus with peripheral circulatory complications/ Diabetic peripheral angiopathy
#     - Code: E11.6, Description: Non-insulin-dependent diabetes mellitus with other specified complications
#     - Code: E11.6+I79.2*, Description: Non-insulin-dependent diabetes mellitus with other specified complications/Peripheral angiopathy in diseases classified elsewhere
#     - Code: E11.6+M14.2*, Description: Non-insulin-dependent diabetes mellitus with other specified complications/Diabetic arthropathy
#     - Code: E11.6+M14.6*, Description: Non-insulin-dependent diabetes mellitus with other specified complications/Diabetic neuropathic arthropathyarthropathy
#     - Code: E11.7, Description: Non-insulin-dependent diabetes mellitus with multiple complications
#     - Code: E11.7+I79.2*, Description: Non-insulin-dependent diabetes mellitus with multiple complications/Peripheral angiopathy in diseases classified elsewhere
#     - Code: E11.8, Description: Non-insulin-dependent diabetes mellitus with unspecified complications
#     - Code: E11.8+I79.2*, Description: Non-insulin-dependent diabetes mellitus with unspecified complications/Peripheral angiopathy in diseases classified elsewhere
#     - Code: E11.9, Description: Non-insulin-dependent diabetes mellitus without complications
#     - Code: E11.9+I79.2*, Description: Non-insulin-dependent diabetes mellitus without complications/Peripheral angiopathy in diseases classified elsewhere
#     - Code: E12.0, Description: Malnutrition-related diabetes mellitus with coma
#     - Code: E12.1, Description: Malnutrition-related diabetes mellitus with ketoacidosis
#     - Code: E12.2+N08.3*, Description: Malnutrition-related diabetes mellitus with renal complications/Insulin-dependent diabetic nephropathy, intracapillary glomerulonephrosis, Kimmelstiel-Wilson syndrome
#     - Code: E12.3+H28.0*, Description: Malnutrition-related diabetes mellitus with ophthalmic complications/ Diabetic cataract
#     - Code: E12.3+H36.0*, Description: Malnutrition-related diabetes mellitus with ophthalmic complications/ Diabetic retinopathy
#     - Code: E12.4+G59.0*, Description: Malnutrition-relatedt diabetes mellitus with neurological complications/ Diabetic mononeuropathy
#     - Code: E12.4+G63.2*, Description: Malnutrition-relateddiabetes mellitus with neurological complications/ Diabetic polyneuropathy
#     - Code: E12.4+G73.0*, Description: Malnutrition-relateddiabetes mellitus with neurological complications/ Diabetic amyotrophy
#     - Code: E12.4+G99.0*, Description: Malnutrition-relateddiabetes mellitus with neurological complications/Daibeteic autonomic neuropathy and or Diabetic autonomic polyneuropathy
#     - Code: E12.5, Description: Malnutrition-related diabetes mellitus with peripheral circulatory complications
#     - Code: E12.5+I79.2*, Description: Malnutrition-related diabetes mellitus with peripheral circulatory complications/ Diabetic peripheral angiopathy
#     - Code: E12.6, Description: Malnutrition-related diabetes mellitus with other specified complications
#     - Code: E12.6+M14.2*, Description: Malnutrition-related  diabetes mellitus with other specified complications/Diabetic arthropathy
#     - Code: E12.6+M14.6*, Description: Malnutrition-related  diabetes mellitus with other specified complications/Diabetic neuropathic arthropathyarthropathy
#     - Code: E12.7, Description: Malnutrition-related diabetes mellitus with multiple complications
#     - Code: E12.8, Description: Malnutrition-related diabetes mellitus with unspecified complications
#     - Code: E12.9, Description: Malnutrition-related diabetes mellitus without complications
#     - Code: O24.1, Description: Pre-existing diabetes mellitus, non-insulin-dependent
#     - Code: O24.2, Description: Pre-existing malnutrition-related diabetes mellitus
#     - Code: O24.3, Description: Pre-existing diabetes mellitus, unspecified
#   Diagnostic Basket:
#     - Procedure/Test: ECG –
# Electrocardiogram, Code: 1232 or
# 1233 or
# 1236, Number Covered: 1
#     - Procedure/Test: Microalbuminuria, Code: 4261 or
# 4262, Number Covered: 1
#     - Procedure/Test: HDL cholesterol, Code: 4028, Number Covered: 1
#     - Procedure/Test: Total cholesterol, Code: 4027, Number Covered: 1
#     - Procedure/Test: LDL cholesterol, Code: 4026, Number Covered: 1
#     - Procedure/Test: Triglycerides, Code: 4147, Number Covered: 1
#     - Procedure/Test: Urine analysis (dipstick), Code: 4188, Number Covered: 1
#     - Procedure/Test: U & E only, Code: 4171, Number Covered: 1
#     - Procedure/Test: Urine creatinine, Code: 4221, Number Covered: 1
#     - Procedure/Test: Glucose –
# random/fasting, Code: 4057, Number Covered: 1
#     - Procedure/Test: Serum creatinine, Code: 4032 or
# 4223, Number Covered: 1
#     - Procedure/Test: Two-hour glucose- OGTT, Code: 4049, Number Covered: 1
#     - Procedure/Test: Two-hour glucose- OGTT, Code: 4049, Number Covered: 1
#     - Procedure/Test: Two-hour glucose- OGTT, Code: 4049, Number Covered: 1
#     - Procedure/Test: Two-hour glucose- OGTT, Code: 4049, Number Covered: 1
#     - Procedure/Test: Two-hour glucose- OGTT, Code: 4049, Number Covered: 1
#     - Procedure/Test: Two-hour glucose- OGTT, Code: 4049, Number Covered: 1
#   Ongoing Management Basket:
#     - Procedure/Test: ECG –
# Electrocardiogram, Code: 1232 or
# 1233 or
# 1236, Number Covered (Tests): 1, Number Covered (Specialists): 1 (Ophthal- mologist)
# 1 (Other Specialist)
#     - Procedure/Test: Microalbuminuria, Code: 4261 or
# 4262, Number Covered (Tests): 2, Number Covered (Specialists): 1 (Ophthal- mologist)
# 1 (Other Specialist)
#     - Procedure/Test: HDL cholesterol, Code: 4028, Number Covered (Tests): 1, Number Covered (Specialists): 1 (Ophthal- mologist)
# 1 (Other Specialist)
#     - Procedure/Test: Total cholesterol, Code: 4027, Number Covered (Tests): 1, Number Covered (Specialists): 1 (Ophthal- mologist)
# 1 (Other Specialist)
#     - Procedure/Test: LDL cholesterol, Code: 4026, Number Covered (Tests): 1, Number Covered (Specialists): 1 (Ophthal- mologist)
# 1 (Other Specialist)
#     - Procedure/Test: Triglycerides, Code: 4147, Number Covered (Tests): 1, Number Covered (Specialists): 1 (Ophthal- mologist)
# 1 (Other Specialist)
#     - Procedure/Test: Urine analysis (dipstick), Code: 4188, Number Covered (Tests): 4, Number Covered (Specialists): 1 (Ophthal- mologist)
# 1 (Other Specialist)
#     - Procedure/Test: U & E only, Code: 4171, Number Covered (Tests): 1, Number Covered (Specialists): 1 (Ophthal- mologist)
# 1 (Other Specialist)
#     - Procedure/Test: Urine creatinine, Code: 4221, Number Covered (Tests): 1, Number Covered (Specialists): 1 (Ophthal- mologist)
# 1 (Other Specialist)
#     - Procedure/Test: HbA1c, Code: 4064, Number Covered (Tests): 4, Number Covered (Specialists): 1 (Ophthal- mologist)
# 1 (Other Specialist)
#     - Procedure/Test: Serum creatinine, Code: 4032 or
# 4223, Number Covered (Tests): 1, Number Covered (Specialists): 1 (Ophthal- mologist)
# 1 (Other Specialist)
#     - Procedure/Test: Tonometry, Code: 3014, Number Covered (Tests): 1, Number Covered (Specialists): 1 (Ophthal- mologist)
# 1 (Other Specialist)
#     - Procedure/Test: Basic capital equipped in own rooms by ophthalmologists, Code: 3009, Number Covered (Tests): 1, Number Covered (Specialists): 1 (Ophthal- mologist)
# 1 (Other Specialist)
#     - Procedure/Test: Fundus examination, Code: 3003 or
# 3004 or
# 3027, Number Covered (Tests): 1, Number Covered (Specialists): 1 (Ophthal- mologist)
# 1 (Other Specialist)
#     - Procedure/Test: Podiatrist, Code: 68301 or
# 68302 or
# 68303 or
# 68304 or, Number Covered (Tests): 1, Number Covered (Specialists): 1 (Ophthal- mologist)
# 1 (Other Specialist)
#     - Procedure/Test: Diabetes Educator, Code: DFSC1, Number Covered (Tests): 1, Number Covered (Specialists): 1 (Ophthal- mologist)
# 1 (Other Specialist)
#     - Procedure/Test: Dietitian, Code: 84200 or
# 84201 or
# 84202 or
# 84203 or
# 84204 or
# 84205, Number Covered (Tests): 1, Number Covered (Specialists): 1 (Ophthal- mologist)
# 1 (Other Specialist)
#   Medicine Information:
#     - CDA Core/Priority/Saver: R 50.00, CDA Executive/Comprehensive: R 50.00, Class: Anti-diabetic agents: Biguanides, Active Ingredient: Metformin, Name/Strength: Accord Metformin                         500mg; 850mg
#     - CDA Core/Priority/Saver: R 50.00, CDA Executive/Comprehensive: R 50.00, Class: Anti-diabetic agents: Biguanides, Active Ingredient: Metformin, Name/Strength: Apex-Metformin                                        500mg
#     - CDA Core/Priority/Saver: R 50.00, CDA Executive/Comprehensive: R 50.00, Class: Anti-diabetic agents: Biguanides, Active Ingredient: Metformin, Name/Strength: Bigsens                           500mg; 850mg; 1000mg
#     - CDA Core/Priority/Saver: R 50.00, CDA Executive/Comprehensive: R 50.00, Class: Anti-diabetic agents: Biguanides, Active Ingredient: Metformin, Name/Strength: Diamin                                         500mg; 850mg
#     - CDA Core/Priority/Saver: R 50.00, CDA Executive/Comprehensive: R 50.00, Class: Anti-diabetic agents: Biguanides, Active Ingredient: Metformin, Name/Strength: Diaphage                        500mg; 850mg; 1000mg
#     - CDA Core/Priority/Saver: R 50.00, CDA Executive/Comprehensive: R 50.00, Class: Anti-diabetic agents: Biguanides, Active Ingredient: Metformin, Name/Strength: Gluconorm                                    500mg; 850mg
#     - CDA Core/Priority/Saver: R 50.00, CDA Executive/Comprehensive: R 50.00, Class: Anti-diabetic agents: Biguanides, Active Ingredient: Metformin, Name/Strength: Fortese                                                   1000mg
#     - CDA Core/Priority/Saver: R 50.00, CDA Executive/Comprehensive: R 50.00, Class: Anti-diabetic agents: Biguanides, Active Ingredient: Metformin, Name/Strength: Mylan Metformin            500mg; 850mg; 1000mg
#     - CDA Core/Priority/Saver: R 50.00, CDA Executive/Comprehensive: R 50.00, Class: Anti-diabetic agents: Biguanides, Active Ingredient: Metformin, Name/Strength: Romidab                         500mg; 850mg; 1000mg
#     - CDA Core/Priority/Saver: R 395.00, CDA Executive/Comprehensive: R 400.00, Class: Anti-diabetic agents: Fast-acting Insulins, Active Ingredient: Insulin Aspart, Name/Strength: Fiasp - penfill 3ml
# (Only Executive and Comprehensive plans)
#     - CDA Core/Priority/Saver: R 395.00, CDA Executive/Comprehensive: R 400.00, Class: Anti-diabetic agents: Fast-acting Insulins, Active Ingredient: Insulin Aspart, Name/Strength: Novorapid - penfill 3ml
# (Not available on KeyCare plans)
#     - CDA Core/Priority/Saver: R 395.00, CDA Executive/Comprehensive: R 400.00, Class: Anti-diabetic agents: Fast-acting Insulins, Active Ingredient: Insulin Glulisine, Name/Strength: Apidra - cartridge 3ml
#     - CDA Core/Priority/Saver: R 700.00, CDA Executive/Comprehensive: R 720.00, Class: Anti-diabetic agents: Intermediate-acting or long-acting combined with fast-acting Insulins (Biphasic), Active Ingredient: Insulin Degludec and Insulin Aspart, Name/Strength: Ryzodeg - penfill 3ml
# (Only Executive and Comprehensive plans)
#     - CDA Core/Priority/Saver: R 700.00, CDA Executive/Comprehensive: R 720.00, Class: Anti-diabetic agents: Intermediate-acting or long-acting combined with fast-acting Insulins (Biphasic), Active Ingredient: Insulin Lispro, Name/Strength: Humalog mix 25 - cartridge 3ml
#     - CDA Core/Priority/Saver: R 700.00, CDA Executive/Comprehensive: R 720.00, Class: Anti-diabetic agents: Intermediate-acting or long-acting combined with fast-acting Insulins (Biphasic), Active Ingredient: Insulin Lispro, Name/Strength: Humalog mix 50 - cartridge 3ml
#     - CDA Core/Priority/Saver: R 440.00, CDA Executive/Comprehensive: R 440.00, Class: Anti-diabetic agents: Long-acting Insulins, Active Ingredient: Insulin Detemir, Name/Strength: Levemir - pre-filled cartridge 3ml
#     - CDA Core/Priority/Saver: R 440.00, CDA Executive/Comprehensive: R 440.00, Class: Anti-diabetic agents: Long-acting Insulins, Active Ingredient: Insulin Glargine, Name/Strength: Optisulin - cartridge 3ml
#     - CDA Core/Priority/Saver: R 125.00, CDA Executive/Comprehensive: R 125.00, Class: Anti-diabetic agents: Sulfonamides, urea derivatives, Active Ingredient: Gliclazide, Name/Strength: Diaran MR *                                               60mg
#     - CDA Core/Priority/Saver: R 125.00, CDA Executive/Comprehensive: R 125.00, Class: Anti-diabetic agents: Sulfonamides, urea derivatives, Active Ingredient: Gliclazide, Name/Strength: Dynacaz MR                           30mg; 60mg; 90mg
#     - CDA Core/Priority/Saver: R 125.00, CDA Executive/Comprehensive: R 125.00, Class: Anti-diabetic agents: Sulfonamides, urea derivatives, Active Ingredient: Gliclazide, Name/Strength: Gliclazide MR Austell                                   60mg
#     - CDA Core/Priority/Saver: R 125.00, CDA Executive/Comprehensive: R 125.00, Class: Anti-diabetic agents: Sulfonamides, urea derivatives, Active Ingredient: Gliclazide, Name/Strength: Gliclazide Unicorn MR                                 30mg
#     - CDA Core/Priority/Saver: R 125.00, CDA Executive/Comprehensive: R 125.00, Class: Anti-diabetic agents: Sulfonamides, urea derivatives, Active Ingredient: Gliclazide, Name/Strength: Gluctam MR                                                60mg
#     - CDA Core/Priority/Saver: R 125.00, CDA Executive/Comprehensive: R 125.00, Class: Anti-diabetic agents: Sulfonamides, urea derivatives, Active Ingredient: Gliclazide, Name/Strength: Glyzid MR                                         30mg; 60mg
#     - CDA Core/Priority/Saver: R 200.00, CDA Executive/Comprehensive: R 215.00, Class: Anti-diabetic agents: Thiazolidinediones, Active Ingredient: Pioglitazone, Name/Strength: Cipla-Pioglitazone                             15mg; 30mg
#     - CDA Core/Priority/Saver: R 200.00, CDA Executive/Comprehensive: R 215.00, Class: Anti-diabetic agents: Thiazolidinediones, Active Ingredient: Pioglitazone, Name/Strength: Pioglitazone hydrochloride Macleods 15mg; 30mg
#     - CDA Core/Priority/Saver: R 30.00, CDA Executive/Comprehensive: R 35.00, Class: Aspirin: Cardiovascular, Active Ingredient: Acetylsalicylic acid, Name/Strength: Aspirin 100 Clicks                                      100mg
#     - CDA Core/Priority/Saver: R 30.00, CDA Executive/Comprehensive: R 35.00, Class: Aspirin: Cardiovascular, Active Ingredient: Acetylsalicylic acid, Name/Strength: Coprin                                                      100mg
#     - CDA Core/Priority/Saver: R 30.00, CDA Executive/Comprehensive: R 35.00, Class: Aspirin: Cardiovascular, Active Ingredient: Acetylsalicylic acid, Name/Strength: Myoprin *                                                 100mg
# (Not available on KeyCare plans)
#     - CDA Core/Priority/Saver: R 30.00, CDA Executive/Comprehensive: R 35.00, Class: Aspirin: Cardiovascular, Active Ingredient: Acetylsalicylic acid, Name/Strength: Trinprin                                                    100mg
#     - CDA Core/Priority/Saver: R 200.00, CDA Executive/Comprehensive: R 200.00, Class: Blood glucose monitoring agents, Active Ingredient: Glucose strips, Name/Strength: Accu check test strip glucose active
# (Not available on KeyCare plans)
#     - CDA Core/Priority/Saver: R 200.00, CDA Executive/Comprehensive: R 200.00, Class: Blood glucose monitoring agents, Active Ingredient: Glucose strips, Name/Strength: Accu check test strip glucose instant
# (Not available on KeyCare plans)
#     - CDA Core/Priority/Saver: R 200.00, CDA Executive/Comprehensive: R 200.00, Class: Blood glucose monitoring agents, Active Ingredient: Glucose strips, Name/Strength: Contour plus blood glucose test strips
# (Not available on KeyCare plans)
#     - CDA Core/Priority/Saver: R 200.00, CDA Executive/Comprehensive: R 200.00, Class: Blood glucose monitoring agents, Active Ingredient: Glucose strips, Name/Strength: Contour ts blood glucose test strips
# (Not available on KeyCare plans)
#     - CDA Core/Priority/Saver: R 200.00, CDA Executive/Comprehensive: R 200.00, Class: Blood glucose monitoring agents, Active Ingredient: Glucose strips, Name/Strength: Glucocheck evolve test strip
#     - CDA Core/Priority/Saver: R 200.00, CDA Executive/Comprehensive: R 200.00, Class: Blood glucose monitoring agents, Active Ingredient: Glucose strips, Name/Strength: Glucocheck key test strip
#     - CDA Core/Priority/Saver: R 200.00, CDA Executive/Comprehensive: R 200.00, Class: Blood glucose monitoring agents, Active Ingredient: Glucose strips, Name/Strength: On call plus blood glucose strips
#     - CDA Core/Priority/Saver: R 200.00, CDA Executive/Comprehensive: R 200.00, Class: Blood glucose monitoring agents, Active Ingredient: Glucose strips, Name/Strength: On call sure blood glucose test strips
#     - CDA Core/Priority/Saver: R 200.00, CDA Executive/Comprehensive: R 200.00, Class: Blood glucose monitoring agents, Active Ingredient: Glucose strips, Name/Strength: Onetouch select plus test strips
#     - CDA Core/Priority/Saver: R 200.00, CDA Executive/Comprehensive: R 200.00, Class: Blood glucose monitoring agents, Active Ingredient: Glucose strips, Name/Strength: Test strip blood glucose clicks bionime gs550
#     - CDA Core/Priority/Saver: R 200.00, CDA Executive/Comprehensive: R 200.00, Class: Blood glucose monitoring agents, Active Ingredient: Glucose strips, Name/Strength: Test strip freestyle optium glucose
# (Not available on KeyCare plans)
#     - CDA Core/Priority/Saver: R 200.00, CDA Executive/Comprehensive: R 200.00, Class: Blood glucose monitoring agents, Active Ingredient: Glucose strips, Name/Strength: Test strip glucocheck connekt
# (Only Executive and Comprehensive plans)
#     - CDA Core/Priority/Saver: R 200.00, CDA Executive/Comprehensive: R 200.00, Class: Blood glucose monitoring agents, Active Ingredient: Glucose strips, Name/Strength: Test strip glucose blood fora 6
# (Not available on KeyCare plans)
#     - CDA Core/Priority/Saver: R 200.00, CDA Executive/Comprehensive: R 200.00, Class: Blood glucose monitoring agents, Active Ingredient: Glucose strips, Name/Strength: Test strip glucose caresens n 29g
#     - CDA Core/Priority/Saver: R 200.00, CDA Executive/Comprehensive: R 200.00, Class: Blood glucose monitoring agents, Active Ingredient: Glucose strips, Name/Strength: Test strip glucose fora diamond blood
#     - CDA Core/Priority/Saver: R 200.00, CDA Executive/Comprehensive: R 200.00, Class: Blood glucose monitoring agents, Active Ingredient: Glucose strips, Name/Strength: Test strip glucose vivachek ino
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Lancets, Name/Strength: Lancet blood collection needle loris
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Lancets, Name/Strength: Lancet fora collection needle sterile 30g
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Lancets, Name/Strength: Lancet fora tender needle sterile 33g
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Lancets, Name/Strength: Lancet freestyle test
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Lancets, Name/Strength: Lancet glucocheck novicheck
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Lancets, Name/Strength: Lancet solus v2
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Lancets, Name/Strength: Lancet unilet sterile 28g
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Lancets, Name/Strength: Lancet unilet sterile 4cm x 6cm x 7.5cm 28g
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Lancets, Name/Strength: Microlet lancet
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Needles, Name/Strength: BD micro fine plus pen needle 30g 8mm
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Needles, Name/Strength: BD micro fine plus pen needle 31g
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Needles, Name/Strength: BD micro fine plus pen needle 32g 4mm
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Needles, Name/Strength: Droplet pen needle 8mm 31g
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Needles, Name/Strength: Needle insulin fora pen 31g 5mm
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Needles, Name/Strength: Needle insulin fora pen 31g 8mm
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Needles, Name/Strength: Needle insulin fora pen 32g 4mm
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Needles, Name/Strength: Needle insulin fora pen 32g 6mm
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Needles, Name/Strength: Needle insulin pen verifine 4mmx10cmx15cm 32g
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Needles, Name/Strength: Needle insulin pen verifine 4mmx10cmx15cm 33g
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Needles, Name/Strength: Needle novofine
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Syringes, Name/Strength: Syringe insulin 1.0ml with 27g needle
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Syringes, Name/Strength: Syringe insulin bd microfine 12.7mm 1ml 9g
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Syringes, Name/Strength: Syringe insulin bd microfine 1ml 8mm 30g
#     - CDA Core/Priority/Saver: R 350.00, CDA Executive/Comprehensive: R 350.00, Class: Surgical item, Active Ingredient: Syringes, Name/Strength: Syringe insulin bd microfine 8mm demi 0.3ml 30g
#
# Condition: Diabetes Insipidus
#   ICD Codes and Descriptions:
#     - Code: E23.2, Description: Diabetes insipidus
#     - Code: N25.1, Description: Nephrogenic diabetes insipidus
#   Diagnostic Basket:
#     - Procedure/Test: U & E only, Code: 4171, Number Covered: 1
#     - Procedure/Test: Creatinine, Code: 4032 or
# 4221 or
# 4223, Number Covered: 1
#     - Procedure/Test: Osmolality: Serum or urine, Code: 4093, Number Covered: 1
#   Ongoing Management Basket:
#     - Procedure/Test: U & E only, Code: 4171, Number Covered (Tests): 3, Number Covered (Specialists): 1
#     - Procedure/Test: Creatinine, Code: 4032 or
# 4221 or
# 4223, Number Covered (Tests): 3, Number Covered (Specialists): 1
#     - Procedure/Test: Osmolality: Serum or urine, Code: 4093, Number Covered (Tests): 1, Number Covered (Specialists): 1
#   Medicine Information:
#     - CDA Core/Priority/Saver: R1 500, CDA Executive/Comprehensive: R1 750, Class: Posterior pituitary hormones: Vasopressin and analogues, Active Ingredient: Desmopressin, Name/Strength: Ddavp nasal spray 5ml                         0.1mg/1ml
#     - CDA Core/Priority/Saver: R1 500, CDA Executive/Comprehensive: R1 750, Class: Posterior pituitary hormones: Vasopressin and analogues, Active Ingredient: Desmopressin, Name/Strength: Minirin melt                    60mcg; 120mcg; 240mcg

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The three required CSV files (`Endocrine CONDITIONS.csv`, `Endocrine MEDICINE.csv`, and `Endocrine TREATMENT.csv`) were successfully loaded into pandas DataFrames named `conditions_df`, `medicine_df`, and `treatment_df`.
# *   The target conditions ("Diabetes Insipidus", "Diabetes Mellitus Type 1", and "Diabetes Mellitus Type 2") are present in all three DataFrames, enabling the mapping of information.
# *   A function `identify_diabetes_mentions` was created to identify mentions of the specified diabetes conditions in clinical notes using a case-insensitive string search.
# *   A function `get_condition_details` was developed to map identified conditions to their corresponding ICD codes, descriptions, treatment protocols (diagnostic and ongoing management baskets), and medicine information from the loaded DataFrames.
# *   A function `generate_report` was implemented to format the extracted condition details into a human-readable report string, including ICD information, treatment procedures/tests with codes and coverage numbers, and medicine details with CDA plans, class, active ingredient, and name/strength.
#
# ### Insights or Next Steps
#
# *   The current method for identifying diabetes mentions is based on simple string matching. A next step would be to integrate a pre-trained clinical language model like ClinicalBERT to perform more sophisticated and context-aware named entity recognition for identifying the conditions.
# *   The generated report provides comprehensive details for each identified condition. Consider enhancing the report formatting for better readability or outputting it in a structured format like JSON for easier programmatic processing.
